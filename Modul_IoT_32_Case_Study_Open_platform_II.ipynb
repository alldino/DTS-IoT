# %% [markdown]
# <a href="https://colab.research.google.com/github/alldino/DTS-IoT/blob/master/Modul_IoT_32_Case_Study_Open_platform_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <html>
#
# <head>
# <meta http-equiv=Content-Type content="text/html; charset=windows-1252">
# <meta name=Generator content="Microsoft Word 15 (filtered)">
# <style>
# <!--
#  /* Font Definitions */
#  @font-face
# 	{font-family:Wingdings;
# 	panose-1:5 0 0 0 0 0 0 0 0 0;}
# @font-face
# 	{font-family:"Cambria Math";
# 	panose-1:2 4 5 3 5 4 6 3 2 4;}
# @font-face
# 	{font-family:Calibri;
# 	panose-1:2 15 5 2 2 2 4 3 2 4;}
#  /* Style Definitions */
#  p.MsoNormal, li.MsoNormal, div.MsoNormal
# 	{margin-top:0cm;
# 	margin-right:0cm;
# 	margin-bottom:8.0pt;
# 	margin-left:0cm;
# 	line-height:107%;
# 	font-size:11.0pt;
# 	font-family:"Calibri",sans-serif;}
# a:link, span.MsoHyperlink
# 	{color:blue;
# 	text-decoration:underline;}
# a:visited, span.MsoHyperlinkFollowed
# 	{color:#954F72;
# 	text-decoration:underline;}
# p
# 	{margin-right:0cm;
# 	margin-left:0cm;
# 	font-size:12.0pt;
# 	font-family:"Times New Roman",serif;}
# p.MsoListParagraph, li.MsoListParagraph, div.MsoListParagraph
# 	{margin-top:0cm;
# 	margin-right:0cm;
# 	margin-bottom:8.0pt;
# 	margin-left:36.0pt;
# 	line-height:107%;
# 	font-size:11.0pt;
# 	font-family:"Calibri",sans-serif;}
# p.MsoListParagraphCxSpFirst, li.MsoListParagraphCxSpFirst, div.MsoListParagraphCxSpFirst
# 	{margin-top:0cm;
# 	margin-right:0cm;
# 	margin-bottom:0cm;
# 	margin-left:36.0pt;
# 	margin-bottom:.0001pt;
# 	line-height:107%;
# 	font-size:11.0pt;
# 	font-family:"Calibri",sans-serif;}
# p.MsoListParagraphCxSpMiddle, li.MsoListParagraphCxSpMiddle, div.MsoListParagraphCxSpMiddle
# 	{margin-top:0cm;
# 	margin-right:0cm;
# 	margin-bottom:0cm;
# 	margin-left:36.0pt;
# 	margin-bottom:.0001pt;
# 	line-height:107%;
# 	font-size:11.0pt;
# 	font-family:"Calibri",sans-serif;}
# p.MsoListParagraphCxSpLast, li.MsoListParagraphCxSpLast, div.MsoListParagraphCxSpLast
# 	{margin-top:0cm;
# 	margin-right:0cm;
# 	margin-bottom:8.0pt;
# 	margin-left:36.0pt;
# 	line-height:107%;
# 	font-size:11.0pt;
# 	font-family:"Calibri",sans-serif;}
# span.comment
# 	{mso-style-name:comment;}
# span.number
# 	{mso-style-name:number;}
# span.string
# 	{mso-style-name:string;}
# .MsoChpDefault
# 	{font-family:"Calibri",sans-serif;}
# .MsoPapDefault
# 	{margin-bottom:8.0pt;
# 	line-height:107%;}
# @page WordSection1
# 	{size:612.0pt 792.0pt;
# 	margin:72.0pt 72.0pt 72.0pt 72.0pt;}
# div.WordSection1
# 	{page:WordSection1;}
#  /* List Definitions */
#  ol
# 	{margin-bottom:0cm;}
# ul
# 	{margin-bottom:0cm;}
# -->
# </style>
#
# </head>
#
# <body lang=EN-ID link=blue vlink="#954F72">
#
# <div class=WordSection1>
#
# <p class=MsoNormal align=center style='margin-bottom:0cm;margin-bottom:.0001pt;
# text-align:center;line-height:150%'><b><span lang=EN-US style='font-size:12.0pt;
# line-height:150%;font-family:"Times New Roman",serif'>AMAZON WEB SERVICE IOT 1 –
# EC2</span></b></p>
#
# <p class=MsoNormal style='margin-bottom:0cm;margin-bottom:.0001pt;line-height:
# 150%'><b><span lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:
# "Times New Roman",serif'>&nbsp;</span></b></p>
#
# <p class=MsoListParagraphCxSpFirst style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:21.3pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><b><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>1.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span></b><b><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>SETTING AWS</span></b></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-bottom:0cm;margin-bottom:
# .0001pt;text-indent:-18.0pt;line-height:150%'><span lang=EN-US
# style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>1.<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; </span></span><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Buka
# halaman web AWS : </span><span lang=EN-US><a href="https://aws.amazon.com/iot/"><span
# style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>https://aws.amazon.com/iot/</span></a></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-bottom:0cm;margin-bottom:
# .0001pt;line-height:150%'><span lang=EN-US><img border=0 width=573 height=299
# id="Picture 4"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image001.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-bottom:0cm;margin-bottom:
# .0001pt;text-indent:-18.0pt;line-height:150%'><span lang=EN-US
# style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>2.<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; </span></span><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Pilih
# Sign In to the Console, dan masuk menggunakan akun masing-masing</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-bottom:0cm;margin-bottom:
# .0001pt;line-height:150%'><span lang=EN-US><img border=0 width=561 height=50
# id="Picture 5"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image002.png"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-bottom:0cm;margin-bottom:
# .0001pt;text-indent:-18.0pt;line-height:150%'><span lang=EN-US
# style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>3.<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; </span></span><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Maka
# tampilan AWS Management Console akan seperti berikut ini</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-bottom:0cm;margin-bottom:
# .0001pt;line-height:150%'><span lang=EN-US><img border=0 width=561 height=293
# id="Picture 6"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image003.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-bottom:0cm;margin-bottom:
# .0001pt;text-indent:-18.0pt;line-height:150%'><span lang=EN-US
# style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>4.<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; </span></span><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Pilih
# menu <b>Services </b>pada bagian kiri atas, maka akan tertampil berbagai macam
# services yang tersedia pada AWS</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-bottom:0cm;margin-bottom:
# .0001pt;line-height:150%'><span lang=EN-US><img border=0 width=562 height=259
# id="Picture 7"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image004.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-bottom:0cm;margin-bottom:
# .0001pt;text-indent:-18.0pt;line-height:150%'><span lang=EN-US
# style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>5.<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; </span></span><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Kemudian
# pilih services <b>EC2</b> pada bagian <b>Compute</b></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-bottom:0cm;margin-bottom:
# .0001pt;line-height:150%'><span lang=EN-US><img border=0 width=504 height=261
# id="Picture 8"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image005.png"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-bottom:0cm;margin-bottom:
# .0001pt;text-indent:-18.0pt;line-height:150%'><span lang=EN-US
# style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>6.<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; </span></span><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Untuk
# tampilan EC2 Dashboard akan seperti berikut ini</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-bottom:0cm;margin-bottom:
# .0001pt;line-height:150%'><span lang=EN-US><img border=0 width=578 height=268
# id="Picture 12"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image006.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-bottom:0cm;margin-bottom:
# .0001pt;text-indent:-18.0pt;line-height:150%'><span lang=EN-US
# style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>7.<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; </span></span><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Pilih
# Launch Instance</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-bottom:0cm;margin-bottom:
# .0001pt;line-height:150%'><span lang=EN-US><img border=0 width=578 height=241
# id="Picture 13"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image007.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-bottom:0cm;margin-bottom:
# .0001pt;text-indent:-18.0pt;line-height:150%'><span lang=EN-US
# style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>8.<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; </span></span><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Isikan
# pada menu Search for AMI </span><span lang=EN-US style='font-size:12.0pt;
# line-height:150%;font-family:Wingdings'>à</span><span lang=EN-US
# style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>
# Ubuntu </span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-bottom:0cm;margin-bottom:
# .0001pt;line-height:150%'><span lang=EN-US><img border=0 width=580 height=209
# id="Picture 14"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image008.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:12.0pt;margin-right:0cm;
# margin-bottom:0cm;margin-left:36.0pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>9.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Pilih <b>Ubuntu Server 18.04 LTS </b>dengan
# <b>64-bit (x86) </b>lalu Select</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:12.0pt;margin-right:0cm;
# margin-bottom:0cm;margin-left:36.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=567 height=204 id="Picture 16"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image009.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:12.0pt;margin-right:0cm;
# margin-bottom:0cm;margin-left:36.0pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>10.<span style='font:7.0pt "Times New Roman"'>&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Pada langkah selanjutnya pilihlah tipe
# yang disarankan (yang berwarna hijau)</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:12.0pt;margin-right:0cm;
# margin-bottom:0cm;margin-left:36.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=107 height=32 id="Picture 22"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image010.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:12.0pt;margin-right:0cm;
# margin-bottom:0cm;margin-left:36.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Kemudian
# pilih <b>Next: Configure Instance </b></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:12.0pt;margin-right:0cm;
# margin-bottom:0cm;margin-left:36.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=566 height=201 id="Picture 17"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image011.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:12.0pt;margin-right:0cm;
# margin-bottom:0cm;margin-left:36.0pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>11.<span style='font:7.0pt "Times New Roman"'>&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Biarkan semua menjadi default. Kemudian
# pilih <b>Next: Add Storage</b></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:12.0pt;margin-right:0cm;
# margin-bottom:0cm;margin-left:36.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=567 height=224 id="Picture 69"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image012.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:12.0pt;margin-right:0cm;
# margin-bottom:0cm;margin-left:36.0pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>12.<span style='font:7.0pt "Times New Roman"'>&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Biarkan default. Kemudian pilih <b>Next:
# Add Storage</b></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:12.0pt;margin-right:0cm;
# margin-bottom:0cm;margin-left:36.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=560 height=223 id="Picture 71"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image013.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:12.0pt;margin-right:0cm;
# margin-bottom:0cm;margin-left:36.0pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>13.<span style='font:7.0pt "Times New Roman"'>&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Pada Step 5. Tambahkan Tag baru dengan
# memilih Add Tag</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:12.0pt;margin-right:0cm;
# margin-bottom:0cm;margin-left:36.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=552 height=222 id="Picture 80"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image014.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:12.0pt;margin-right:0cm;
# margin-bottom:0cm;margin-left:36.0pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>14.<span style='font:7.0pt "Times New Roman"'>&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Isikan <b>Key </b>dengan nama Anda dan <b>Value
# </b>dengan <b>Dev-Server.</b> Kemudian pilih <b>Next: Configure Security Group</b></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:12.0pt;margin-right:0cm;
# margin-bottom:0cm;margin-left:36.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=569 height=49 id="Picture 81"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image015.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:12.0pt;margin-right:0cm;
# margin-bottom:0cm;margin-left:36.0pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>15.<span style='font:7.0pt "Times New Roman"'>&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Pada Step 6</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:12.0pt;margin-right:0cm;
# margin-bottom:0cm;margin-left:36.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Isikan
# <b>Security group name </b>dengan <b>dev-appserver-secgroup</b></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:12.0pt;margin-right:0cm;
# margin-bottom:0cm;margin-left:36.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Isikan
# <b>Description </b>dengan <b>basic secgroup for development server (web)</b></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:12.0pt;margin-right:0cm;
# margin-bottom:0cm;margin-left:36.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Tambahkan
# <b>Rule </b>berupa HTTP dengan protocol TCP dan Port Range 80.</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:12.0pt;margin-right:0cm;
# margin-bottom:0cm;margin-left:36.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Kemudian
# pilih <b>Review and Launch</b></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:12.0pt;margin-right:0cm;
# margin-bottom:0cm;margin-left:36.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=560 height=226 id="Picture 86"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image016.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:12.0pt;margin-right:0cm;
# margin-bottom:0cm;margin-left:36.0pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>16.<span style='font:7.0pt "Times New Roman"'>&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Pada Step 7 maka akan tertampil Review
# Instance Launch yang kita ingginkan tadi. Jika sudah benar maka pilih <b>Launch</b></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:12.0pt;margin-right:0cm;
# margin-bottom:0cm;margin-left:36.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=559 height=222 id="Picture 91"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image017.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:12.0pt;margin-right:0cm;
# margin-bottom:0cm;margin-left:36.0pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>17.<span style='font:7.0pt "Times New Roman"'>&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Setelah pilih Launch maka akan tertampil
# dialog box Key Pair sebagai semacam sertifikat untuk mengakses Launch yang
# sudah kita buat tadi.</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:12.0pt;margin-right:0cm;
# margin-bottom:0cm;margin-left:36.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Pilih
# <b>Create a new key pair </b></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:12.0pt;margin-right:0cm;
# margin-bottom:0cm;margin-left:36.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Isikan
# nama Key Pair dengan <b>tutoriallinux-aws-service</b></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:12.0pt;margin-right:0cm;
# margin-bottom:0cm;margin-left:36.0pt;margin-bottom:.0001pt;line-height:150%'><b><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Jangan
# lupa download KEY PAIR.</span></b></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:12.0pt;margin-right:0cm;
# margin-bottom:0cm;margin-left:36.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Kemudian
# pilih <b>Launch Instance</b></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:12.0pt;margin-right:0cm;
# margin-bottom:0cm;margin-left:36.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=528 height=380 id="Picture 93"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image018.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:12.0pt;margin-right:0cm;
# margin-bottom:0cm;margin-left:36.0pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>18.<span style='font:7.0pt "Times New Roman"'>&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Maka akan tertampil Launch Status anda</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:12.0pt;margin-right:0cm;
# margin-bottom:0cm;margin-left:36.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=528 height=140 id="Picture 94"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image019.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:12.0pt;margin-right:0cm;
# margin-bottom:0cm;margin-left:36.0pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>19.<span style='font:7.0pt "Times New Roman"'>&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Pilih View Instances pada bagian bawah</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:12.0pt;margin-right:0cm;
# margin-bottom:0cm;margin-left:36.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=128 height=45 id="Picture 99"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image020.png"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:12.0pt;margin-right:0cm;
# margin-bottom:0cm;margin-left:36.0pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>20.<span style='font:7.0pt "Times New Roman"'>&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Maka pada dashboard EC2 pada bagian
# Instances akan tertampil seperti berikut (daftar Intsance)</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:12.0pt;margin-right:0cm;
# margin-bottom:0cm;margin-left:36.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=549 height=123 id="Picture 102"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image021.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:12.0pt;margin-right:0cm;
# margin-bottom:0cm;margin-left:36.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>&nbsp;</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:21.3pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><b><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>2.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span></b><b><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>KONFIGURASI PUTTY FOR WINDOWS</span></b></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>1.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Download Putty for Windows. Buka web
# berikut : </span><span lang=EN-US><a
# href="https://www.chiark.greenend.org.uk/~sgtatham/putty/latest.html"><span
# style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>https://www.chiark.greenend.org.uk/~sgtatham/putty/latest.html</span></a></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=555 height=232 id="Picture 105"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image022.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Pilih
# sesuai bit computer anda!</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>2.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Install Putty dan jalankan setelah selesai
# proses instalasinya</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=353 height=350 id="Picture 106"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image023.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>3.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Kemudian jalankan Puttygen pada menu Start
# Windows</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=260 height=154 id="Picture 107"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image024.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Atau
# bisa dibuka pada folder instalasi PuTTY</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=483 height=246 id="Picture 108"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image025.jpg"></span><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'> </span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Maka
# akan tertampil Menu Puttygen</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=384 height=380 id="Picture 110"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image026.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>4.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Kemudian pilih Load dan pilih Key Pair
# yang sebelumnya Anda download saat instalasi Instance Launch. Kemudian pilih
# Open</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=484 height=375 id="Picture 111"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image027.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>5.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Maka akan tertampil pesan Sukses seperti
# berikut. Kemudian pilih Ok</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=326 height=325 id="Picture 112"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image028.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>6.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Kemudian <b>Save private key </b>di folder
# yang sama dengan Key Pair tadi dan dengan nama yang sama pula. <b><span
# style='background:yellow'>Jangan lupa save dengan format .ppk</span></b></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=543 height=420 id="Picture 113"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image029.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>7.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Maka akan tertampil file <b>ppk </b>yang
# kita simpan tadi dengan format <b>.ppk</b></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=552 height=48 id="Picture 114"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image030.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>8.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Buka kembali web Instance Launch. Pada
# kolom Description di bawah, copy <b>Public DNS (IPv4).</b> </span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=573 height=70 id="Picture 116"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image031.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>9.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Paste-kan Public DNS (IPv4) ke Host Name
# PuTTY</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=392 height=390 id="Picture 117"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image032.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>10.<span style='font:7.0pt "Times New Roman"'>&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Kemudian pada Jendela PuTTY bagian
# Category, pilih Connection </span><span lang=EN-US style='font-size:12.0pt;
# line-height:150%;font-family:Wingdings'>à</span><span lang=EN-US
# style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>
# SSH </span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:Wingdings'>à</span><span lang=EN-US style='font-size:12.0pt;
# line-height:150%;font-family:"Times New Roman",serif'> Auth</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=373 height=368 id="Picture 118"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image033.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>11.<span style='font:7.0pt "Times New Roman"'>&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Pada <b>Private key file for
# authentication </b>pilih Browse dan carilah file <b>.ppk </b>yang sudah Anda
# buat sebelumya dan klik Open</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=518 height=126 id="Picture 121"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image034.png"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>12.<span style='font:7.0pt "Times New Roman"'>&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Setelah terisi kemudain pilih Open</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=300 height=191 id="Picture 123"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image035.png"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>13.<span style='font:7.0pt "Times New Roman"'>&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Maka akan tertampil pesan sebagai berikut.
# Kemudian pilih saja <b>Yes</b></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=541 height=349 id="Picture 124"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image036.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>14.<span style='font:7.0pt "Times New Roman"'>&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Maka akan tertampil sebegai berikut</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=421 height=117 id="Picture 125"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image037.png"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>15.<span style='font:7.0pt "Times New Roman"'>&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Login saja sebagai <b>ubuntu</b></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=392 height=55 id="Picture 126"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image038.png"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>16.<span style='font:7.0pt "Times New Roman"'>&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Maka akan tertampil seperti berikut</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=556 height=369 id="Picture 127"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image039.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>17.<span style='font:7.0pt "Times New Roman"'>&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Jika sudah bisa seperti diatas maka Anda
# sudah bisa mengakses Ubuntu anda lewat PuTTY</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=269 height=61 id="Picture 128"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image040.png"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><b><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>&nbsp;</span></b></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><b><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>&nbsp;</span></b></p>
#
# <p class=MsoListParagraphCxSpLast style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><b><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>&nbsp;</span></b></p>
#
# <p class=MsoNormal style='margin-bottom:0cm;margin-bottom:.0001pt;line-height:
# 150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:
# "Times New Roman",serif'>&nbsp;</span></p>
#
# <p class=MsoListParagraphCxSpFirst style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:21.3pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><b><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>3.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span></b><b><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>AKSES DESKTOP UBUNTU DARI WINDOWS</span></b></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>1.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Pada terminal ubuntu yang sudah bisa diakses
# ketikkan perintah berikut</span></p>
#
# <p class=MsoListParagraphCxSpLast style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:72.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif;
# background:yellow'>sudo apt update &amp;&amp; sudo apt upgrade</span></p>
#
# <p class=MsoNormal style='margin-bottom:0cm;margin-bottom:.0001pt;line-height:
# 150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:
# "Times New Roman",serif'>            </span><span lang=EN-US><img border=0
# width=475 height=155 id="Picture 129"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image041.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpFirst style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>2.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Kemudian ketikkan perintah untuk memberi
# akses windows </span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:72.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif;
# background:yellow'>sudo sed –i ‘s/^PasswordAuthentication
# no/PasswordAuthentication yes/’ /etc/ssh/sshd_config</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>3.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Kemudian ketikkan perintah untuk mengaktifkan
# kondisi yang sudah kita ubah tadi</span></p>
#
# <p class=MsoListParagraphCxSpLast style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:72.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif;
# background:yellow'>sudo /etc/init.d/ssh restart</span><span lang=EN-US
# style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'> </span></p>
#
# <p class=MsoNormal style='margin-bottom:0cm;margin-bottom:.0001pt;line-height:
# 150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:
# "Times New Roman",serif'>            </span><span lang=EN-US><img border=0
# width=453 height=43 id="Picture 130"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image042.png"></span></p>
#
# <p class=MsoListParagraph style='margin-top:0cm;margin-right:0cm;margin-bottom:
# 0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;line-height:
# 150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:
# "Times New Roman",serif'>4.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Ketikkan perintah dibawah untuk merubah
# password menjadi baru. Ketikkan password dan ingat password Ubuntu anda</span></p>
#
# <p class=MsoNormal style='margin-top:0cm;margin-right:0cm;margin-bottom:0cm;
# margin-left:72.0pt;margin-bottom:.0001pt;line-height:150%'><span lang=EN-US
# style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif;
# background:yellow'>sudo passwd ubuntu</span></p>
#
# <p class=MsoListParagraphCxSpFirst style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=389 height=78 id="Picture 131"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image043.png"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>5.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Install Ubuntu desktop environment yakni
# xfce4 dan virtual network computer dengan perintah berikut</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:72.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif;
# background:yellow'>sudo apt install xrdp xfce4 xfce4-goodies tightvncserver</span><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>
# </span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>6.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Setting xcfe4 environment untuk RDP
# Connection mmenggunakan perintah berikut. RDP adalah Remote Desktop Protocol
# yang digunakan untuk menghubungkan computer satu dengan yyang lainnya dalam
# konesksi jaringan.</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:72.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif;
# background:yellow'>echo xfce4-session&gt; /home/ubuntu/.xsession</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>7.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Ketikkan perintah berikut untuk
# memindahkan xsession ke folder /etc/skel untuk membuat default window manager </span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:72.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif;
# background:yellow'>sudo cp /home/ubuntu/.xsession /etc/skel</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>8.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Ketikkan perintah berikut untuk
# mengijinkan koneksi ke port yang ingin dihubungkan</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:72.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif;
# background:yellow'>sudo sed –i ‘0,/-1/s//ask-1/’ /etc/xrdp/xrdp.ini</span><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>
# </span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>9.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Kemudian restart xrdp dengan perintah
# beriikut</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:72.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif;
# background:yellow'>sudo service xrdp restart</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>10.<span style='font:7.0pt "Times New Roman"'>&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Kemudian restart Ubuntu dengan mengetikkan
# perintah berikut</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:72.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif;
# background:yellow'>sudo reboot now</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>11.<span style='font:7.0pt "Times New Roman"'>&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Buka kembali PuTTY. Pilih Category <b>Connection
# </b></span><b><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:Wingdings'>à</span></b><b><span lang=EN-US style='font-size:12.0pt;
# line-height:150%;font-family:"Times New Roman",serif'> SSH </span></b><b><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:Wingdings'>à</span></b><b><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>
# Tunnels</span></b></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=443 height=230 id="Picture 132"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image044.png"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>12.<span style='font:7.0pt "Times New Roman"'>&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Isikan pada <b>Source port </b>dengan 8888</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Pada<b>
# Destination </b>isikan <b>Private IPs:3389</b></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Kemudian
# tekan Add</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=455 height=166 id="Picture 134"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image045.png"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Menjadi
# seperti berikut. Kemudian pilih <b>Open</b></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=295 height=226 id="Picture 136"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image046.png"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>13.<span style='font:7.0pt "Times New Roman"'>&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Kembali ke menu Session kemudian Save</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=451 height=333 id="Picture 137"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image047.png"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>14.<span style='font:7.0pt "Times New Roman"'>&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Pada Host Name kita isikan kembali <b>Public
# DNS (IPv4)</b></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Dan
# pada menu <b>Connection </b></span><b><span lang=EN-US style='font-size:12.0pt;
# line-height:150%;font-family:Wingdings'>à</span></b><b><span lang=EN-US
# style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>
# SSH </span></b><b><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:Wingdings'>à</span></b><b><span lang=EN-US style='font-size:12.0pt;
# line-height:150%;font-family:"Times New Roman",serif'> Auth, </span></b><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>masukkan
# kembali key pair.</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Dan
# pilih <b>Save, </b>kemudian Open</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=387 height=378 id="Picture 138"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image048.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>15.<span style='font:7.0pt "Times New Roman"'>&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Masuk kembali sebagai Login as <b>ubuntu</b></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Cek
# dengan perintah berikut </span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=516 height=277 id="Picture 139"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image049.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Maka
# akan tertampil local address 127.0.0. … (ini yang akan kita gunakan untuk
# remote desktop connection</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>16.<span style='font:7.0pt "Times New Roman"'>&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Buka web berikut</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><a
# href="https://www.microsoft.com/en-us/download/details.aspx?id=44989"><span
# style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>https://www.microsoft.com/en-us/download/details.aspx?id=44989</span></a></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>dan
# download Remote Desktop Connection dan install</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Kemudian
# buka Remote Desktop Connection </span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=530 height=125 id="Picture 140"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image050.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>&nbsp;</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Jendela
# RDC akan demikian </span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=340 height=214 id="Picture 141"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image051.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>17.<span style='font:7.0pt "Times New Roman"'>&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Masukkan IP local computer dengan <b>127.0.0.1:8888</b></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=354 height=220 id="Picture 142"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image052.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Kemudian
# pilih <b>Connect</b></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>18.<span style='font:7.0pt "Times New Roman"'>&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Akan tertampil Warning seperti berikut,
# lalu tekan Yes saja</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=383 height=239 id="Picture 143"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image053.png"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>19.<span style='font:7.0pt "Times New Roman"'>&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Akan tertampil Dekstop Login untuk Ubuntu
# Instance kita</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Masukkan
# username sebagai <b>ubuntu </b></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Masukkan
# password yang sudah kita buat tadi<b> pada langkah 4</b></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><b><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Pilih
# Ok. </span></b></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=517 height=388 id="Picture 145"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image054.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>20.<span style='font:7.0pt "Times New Roman"'>&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Akan tertampil Desktop Ubuntu instance
# kita</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=532 height=343 id="Picture 146"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image055.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>21.<span style='font:7.0pt "Times New Roman"'>&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Yeay !! Selamat anda bisa menggunakan
# ubuntu wwkwkw</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:108.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>&nbsp;</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:108.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>&nbsp;</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:108.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>&nbsp;</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:108.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>&nbsp;</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:108.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>&nbsp;</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:108.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>&nbsp;</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:108.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>&nbsp;</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:108.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>&nbsp;</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:108.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>&nbsp;</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:108.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>&nbsp;</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:108.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>&nbsp;</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:108.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>&nbsp;</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:108.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>&nbsp;</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:108.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>&nbsp;</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:108.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>&nbsp;</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:108.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>&nbsp;</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:108.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>&nbsp;</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:21.3pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><b><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>4.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span></b><b><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>INSTALASI THINGER.IO PADA UBUNTU ISNTANCE</span></b></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:21.3pt;margin-bottom:.0001pt;text-indent:21.25pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Kali ini anda akan membuat open iot
# platform Thinger.io dalam kondisi menggunakan server Ubuntu anda.</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span class=MsoHyperlink><span lang=EN-US style='font-size:
# 12.0pt;line-height:150%;font-family:"Times New Roman",serif;color:windowtext;
# text-decoration:none'>1.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Buka web thinger.io </span><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:Wingdings'>à</span><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>
# </span><span lang=EN-US><a href="https://thinger.io/"><span style='font-size:
# 12.0pt;line-height:150%;font-family:"Times New Roman",serif'>https://thinger.io/</span></a></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# class=MsoHyperlink><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif;color:windowtext;text-decoration:none'>Pilih
# Downloads</span></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=516 height=74 id="Picture 148"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image056.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>2.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Pilih Ubuntu </span><span lang=EN-US
# style='font-size:12.0pt;line-height:150%;font-family:Wingdings'>à</span><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>
# Install Instructions </span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=362 height=259 id="Picture 149"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image057.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>3.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Ketikkan perintah berikut ini pada
# terminal ubuntu instance anda pada RDC</span></p>
#
# <p class=MsoListParagraphCxSpLast style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:72.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:10.0pt;line-height:150%;font-family:"Courier New";
# color:black;letter-spacing:-.75pt;background:#F3F6FB'>sudo apt update</span></p>
#
# <p class=MsoNormal style='margin-bottom:0cm;margin-bottom:.0001pt;line-height:
# 150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:
# "Times New Roman",serif;color:black;letter-spacing:-.75pt;background:#F3F6FB'>                Kemudian
# </span></p>
#
# <p class=MsoListParagraph style='margin-top:0cm;margin-right:0cm;margin-bottom:
# 0cm;margin-left:72.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:10.0pt;line-height:150%;font-family:"Courier New";
# color:black;letter-spacing:-.75pt;background:#F3F6FB'>sudo apt upgrade</span></p>
#
# <p class=MsoNormal style='margin-bottom:0cm;margin-bottom:.0001pt;line-height:
# 150%'><span lang=EN-US style='font-size:16.0pt;line-height:150%;font-family:
# "Times New Roman",serif'>          </span><span lang=EN-US><img border=0
# width=538 height=246 id="Picture 151"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image058.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpFirst style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>4.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Instalasi MongoDB karena ThingerIO
# membutuhkan server MongoDB untuk menyimpan informasi. Ketikkan perintah berikut
# ini untuk memasukkan public key untuk manajemen sistem</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:72.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:10.0pt;line-height:150%;font-family:"Courier New";
# color:black;letter-spacing:-.75pt;background:#F3F6FB'>sudo apt-key adv
# --keyserver hkp:</span><span class=comment><span lang=EN-US style='font-size:
# 10.0pt;line-height:150%;font-family:"Courier New";letter-spacing:-.75pt'>//keyserver.ubuntu.com:</span></span><span
# class=number><span lang=EN-US style='font-size:10.0pt;line-height:150%;
# font-family:"Courier New";letter-spacing:-.75pt'>80</span></span><span
# class=comment><span lang=EN-US style='font-size:10.0pt;line-height:150%;
# font-family:"Courier New";letter-spacing:-.75pt'> --recv </span></span><span
# class=number><span lang=EN-US style='font-size:10.0pt;line-height:150%;
# font-family:"Courier New";letter-spacing:-.75pt'>0</span></span><span
# class=comment><span lang=EN-US style='font-size:10.0pt;line-height:150%;
# font-family:"Courier New";letter-spacing:-.75pt'>C</span></span><span
# class=number><span lang=EN-US style='font-size:10.0pt;line-height:150%;
# font-family:"Courier New";letter-spacing:-.75pt'>49</span></span><span
# class=comment><span lang=EN-US style='font-size:10.0pt;line-height:150%;
# font-family:"Courier New";letter-spacing:-.75pt'>F</span></span><span
# class=number><span lang=EN-US style='font-size:10.0pt;line-height:150%;
# font-family:"Courier New";letter-spacing:-.75pt'>3730359</span></span><span
# class=comment><span lang=EN-US style='font-size:10.0pt;line-height:150%;
# font-family:"Courier New";letter-spacing:-.75pt'>A</span></span><span
# class=number><span lang=EN-US style='font-size:10.0pt;line-height:150%;
# font-family:"Courier New";letter-spacing:-.75pt'>14518585931</span></span><span
# class=comment><span lang=EN-US style='font-size:10.0pt;line-height:150%;
# font-family:"Courier New";letter-spacing:-.75pt'>BC</span></span><span
# class=number><span lang=EN-US style='font-size:10.0pt;line-height:150%;
# font-family:"Courier New";letter-spacing:-.75pt'>711</span></span><span
# class=comment><span lang=EN-US style='font-size:10.0pt;line-height:150%;
# font-family:"Courier New";letter-spacing:-.75pt'>F</span></span><span
# class=number><span lang=EN-US style='font-size:10.0pt;line-height:150%;
# font-family:"Courier New";letter-spacing:-.75pt'>9</span></span><span
# class=comment><span lang=EN-US style='font-size:10.0pt;line-height:150%;
# font-family:"Courier New";letter-spacing:-.75pt'>BA</span></span><span
# class=number><span lang=EN-US style='font-size:10.0pt;line-height:150%;
# font-family:"Courier New";letter-spacing:-.75pt'>15703</span></span><span
# class=comment><span lang=EN-US style='font-size:10.0pt;line-height:150%;
# font-family:"Courier New";letter-spacing:-.75pt'>C</span></span><span
# class=number><span lang=EN-US style='font-size:10.0pt;line-height:150%;
# font-family:"Courier New";letter-spacing:-.75pt'>6</span></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>5.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'> Ketikkan perintah berikut untuk membuat
# daftar file untuk MongoDB</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:70.9pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:10.0pt;line-height:150%;font-family:"Courier New";
# color:black;letter-spacing:-.75pt;background:#F3F6FB'>echo </span><span
# class=string><span lang=EN-US style='font-size:10.0pt;line-height:150%;
# font-family:"Courier New";letter-spacing:-.75pt'>&quot;deb [ arch=amd</span></span><span
# class=number><span lang=EN-US style='font-size:10.0pt;line-height:150%;
# font-family:"Courier New";letter-spacing:-.75pt'>64</span></span><span
# class=string><span lang=EN-US style='font-size:10.0pt;line-height:150%;
# font-family:"Courier New";letter-spacing:-.75pt'>,arm</span></span><span
# class=number><span lang=EN-US style='font-size:10.0pt;line-height:150%;
# font-family:"Courier New";letter-spacing:-.75pt'>64</span></span><span
# class=string><span lang=EN-US style='font-size:10.0pt;line-height:150%;
# font-family:"Courier New";letter-spacing:-.75pt'> ] http:</span></span><span
# class=comment><span lang=EN-US style='font-size:10.0pt;line-height:150%;
# font-family:"Courier New";letter-spacing:-.75pt'>//repo.mongodb.org/apt/ubuntu
# xenial/mongodb-org/</span></span><span class=number><span lang=EN-US
# style='font-size:10.0pt;line-height:150%;font-family:"Courier New";letter-spacing:
# -.75pt'>3.4</span></span><span class=comment><span lang=EN-US style='font-size:
# 10.0pt;line-height:150%;font-family:"Courier New";letter-spacing:-.75pt'>
# multiverse&quot;</span></span><span class=string><span lang=EN-US
# style='font-size:10.0pt;line-height:150%;font-family:"Courier New";letter-spacing:
# -.75pt'> | sudo tee /etc/apt/sources.list.d/mongodb-org-</span></span><span
# class=number><span lang=EN-US style='font-size:10.0pt;line-height:150%;
# font-family:"Courier New";letter-spacing:-.75pt'>3.4</span></span><span
# class=string><span lang=EN-US style='font-size:10.0pt;line-height:150%;
# font-family:"Courier New";letter-spacing:-.75pt'>.list</span></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>6.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'> Kemudian reload local database dengan
# perintah berikut ini</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:71.45pt;margin-bottom:.0001pt;text-indent:.55pt;
# line-height:150%'><span lang=EN-US style='font-size:10.0pt;line-height:150%;
# font-family:"Courier New";color:black;letter-spacing:-.75pt;background:#F3F6FB'>sudo
# apt update</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>7.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Kemudian install paket file MongoDB dengan
# menggunakan perintah berikut ini</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:72.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:10.0pt;line-height:150%;font-family:"Courier New";
# color:black;letter-spacing:-.75pt;background:#F3F6FB'>sudo apt install -y
# mongodb-org</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>8.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Edit file mongodb.service untuk
# menjalankan service dari MongoDB</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:72.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:10.0pt;line-height:150%;font-family:"Courier New";
# color:black;letter-spacing:-.75pt;background:#F3F6FB'>sudo nano
# /etc/systemd/system/mongodb.service</span></p>
#
# <p class=MsoListParagraphCxSpLast style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Paste-kan
# code dibawah ini</span></p>
#
# <p class=MsoNormal style='margin-left:36.0pt;text-indent:36.0pt'><span
# lang=EN-US style='font-size:10.0pt;line-height:107%;font-family:"Courier New";
# color:black;letter-spacing:-.75pt;background:#F3F6FB'>[Unit]</span></p>
#
# <p class=MsoNormal style='margin-top:0cm;margin-right:0cm;margin-bottom:0cm;
# margin-left:36.0pt;margin-bottom:.0001pt;text-indent:36.0pt;line-height:normal'><span
# lang=EN-US style='font-size:10.0pt;font-family:"Courier New";color:black;
# letter-spacing:-.75pt;background:#F3F6FB'>Description=High-performance,
# schema-free document-oriented database</span></p>
#
# <p class=MsoNormal style='margin-top:0cm;margin-right:0cm;margin-bottom:0cm;
# margin-left:36.0pt;margin-bottom:.0001pt;text-indent:36.0pt;line-height:normal'><span
# lang=EN-US style='font-size:10.0pt;font-family:"Courier New";color:black;
# letter-spacing:-.75pt;background:#F3F6FB'>After=network.target</span></p>
#
# <p class=MsoNormal style='margin-bottom:0cm;margin-bottom:.0001pt;line-height:
# normal'><span lang=EN-US style='font-size:10.0pt;font-family:"Courier New";
# letter-spacing:-.75pt;background:#F3F6FB'>&nbsp;</span></p>
#
# <p class=MsoNormal style='margin-top:0cm;margin-right:0cm;margin-bottom:0cm;
# margin-left:36.0pt;margin-bottom:.0001pt;text-indent:36.0pt;line-height:normal'><span
# lang=EN-US style='font-size:10.0pt;font-family:"Courier New";color:black;
# letter-spacing:-.75pt;background:#F3F6FB'>[Service]</span></p>
#
# <p class=MsoNormal style='margin-top:0cm;margin-right:0cm;margin-bottom:0cm;
# margin-left:36.0pt;margin-bottom:.0001pt;text-indent:36.0pt;line-height:normal'><span
# lang=EN-US style='font-size:10.0pt;font-family:"Courier New";color:black;
# letter-spacing:-.75pt;background:#F3F6FB'>User=mongodb</span></p>
#
# <p class=MsoNormal style='margin-top:0cm;margin-right:0cm;margin-bottom:0cm;
# margin-left:36.0pt;margin-bottom:.0001pt;text-indent:36.0pt;line-height:normal'><span
# lang=EN-US style='font-size:10.0pt;font-family:"Courier New";color:black;
# letter-spacing:-.75pt;background:#F3F6FB'>ExecStart=/usr/bin/mongod --quiet
# --config /etc/mongod.conf</span></p>
#
# <p class=MsoNormal style='margin-bottom:0cm;margin-bottom:.0001pt;line-height:
# normal'><span lang=EN-US style='font-size:10.0pt;font-family:"Courier New";
# letter-spacing:-.75pt;background:#F3F6FB'>&nbsp;</span></p>
#
# <p class=MsoNormal style='margin-top:0cm;margin-right:0cm;margin-bottom:0cm;
# margin-left:36.0pt;margin-bottom:.0001pt;text-indent:36.0pt;line-height:normal'><span
# lang=EN-US style='font-size:10.0pt;font-family:"Courier New";color:black;
# letter-spacing:-.75pt;background:#F3F6FB'>[Install]</span></p>
#
# <p class=MsoListParagraphCxSpFirst style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:71.45pt;margin-bottom:.0001pt;text-indent:.55pt;
# line-height:150%'><span lang=EN-US style='font-size:10.0pt;line-height:150%;
# font-family:"Courier New";color:black;letter-spacing:-.75pt;background:#F3F6FB'>WantedBy=multi-user.target</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Jangan
# lupa simpan dengan<b> tekan Ctrl + X </b>kemudian<b> tekan Y </b>baru<b> Enter</b></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>9.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Untuk memulai system dari MongoDB ketikkan
# perintah berikut ini</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:72.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:10.0pt;line-height:150%;font-family:"Courier New";
# color:black;letter-spacing:-.75pt;background:#F3F6FB'>sudo systemctl start
# mongodb</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Kemudian</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>            </span><span
# lang=EN-US style='font-size:10.0pt;line-height:150%;font-family:"Courier New";
# color:#505050;letter-spacing:-.75pt;background:#F3F6FB'>sudo systemctl enable
# mongodb</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>10.<span style='font:7.0pt "Times New Roman"'>&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Untuk mengecek apakah MongoDB sudah jalan
# atau belum, gunakan perintah berikut</span></p>
#
# <p class=MsoListParagraphCxSpLast style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:71.45pt;margin-bottom:.0001pt;text-indent:.55pt;
# line-height:150%'><span lang=EN-US style='font-size:10.0pt;line-height:150%;
# font-family:"Courier New";color:#505050;letter-spacing:-.75pt;background:#F3F6FB'>sudo
# systemctl status mongodb</span></p>
#
# <p class=MsoNormal style='margin-bottom:0cm;margin-bottom:.0001pt;line-height:
# 150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:
# "Times New Roman",serif'>            </span><span lang=EN-US><img border=0
# width=558 height=159 id="Picture 152"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image059.jpg"></span></p>
#
# <p class=MsoNormal style='margin-bottom:0cm;margin-bottom:.0001pt;line-height:
# 150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:
# "Times New Roman",serif'>            Tekan <b>Ctrl + C </b>untuk exit perintah</span></p>
#
# <p class=MsoListParagraphCxSpFirst style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>11.<span style='font:7.0pt "Times New Roman"'>&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Install ThingerIO dengan menggunkan
# perintah berikut ini</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:71.45pt;margin-bottom:.0001pt;text-indent:.55pt;
# line-height:150%'><span lang=EN-US style='font-size:10.0pt;line-height:150%;
# font-family:"Courier New";color:#505050;letter-spacing:-.75pt;background:#F3F6FB'>sudo
# snap install thinger-maker-server</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Jika
# sudah terinstall maka akan tertampil pada terminal</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=559 height=36 id="Picture 153"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image060.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>12.<span style='font:7.0pt "Times New Roman"'>&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Untuk mengecek status dari ThingerIO
# dengan meggunakan perintah berikut</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:71.45pt;margin-bottom:.0001pt;text-indent:.55pt;
# line-height:150%'><span lang=EN-US style='font-size:10.0pt;line-height:150%;
# font-family:"Courier New";color:#505050;letter-spacing:-.75pt;background:#F3F6FB'>sudo
# service snap.thinger-maker-server.thingerd status</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Maka
# akan tertampil pada terminal</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=553 height=137 id="Picture 154"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image061.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Tekan
# <b>Ctrl + C </b>untuk exit perintah</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>13.<span style='font:7.0pt "Times New Roman"'>&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Pada terminal, install browser yang
# memadai seperti Mozila Firefox, or something. Bisa menggunakan perintah berikut
# untuk Mozila Firefox</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:72.0pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:10.0pt;line-height:150%;font-family:"Courier New";
# color:#505050;letter-spacing:-.75pt;background:#F3F6FB'>sudo apt-get install
# firefox</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>&nbsp;</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>&nbsp;</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>&nbsp;</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>&nbsp;</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>&nbsp;</span></p>
#
# <p class=MsoListParagraphCxSpLast style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>&nbsp;</span></p>
#
# <p class=MsoNormal style='margin-bottom:0cm;margin-bottom:.0001pt;line-height:
# 150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:
# "Times New Roman",serif'>&nbsp;</span></p>
#
# <p class=MsoListParagraphCxSpFirst style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:21.3pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><b><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>5.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span></b><b><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>KONFIGURASI PORT YANG DIGUNAKAN UNTUK
# KOMUNIKASI TCP PADA UBUNTU ISNTANCE</span></b></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:42.55pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>1.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Buka Ubuntu Instance anda (pastikan sudah
# running)</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:42.55pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Pilih
# pada bagian tab <b>Description </b>pada bagian <b>Security groups. </b>Pilih
# pada Group Name (yang berwarna kuning)</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:42.55pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=551 height=303 id="Picture 24"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image062.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:42.55pt;margin-bottom:.0001pt;line-height:150%'><b><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'> </span></b><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Kemudian
# akan tertampil tab menu <b>Inbound</b></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:42.55pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=595 height=208 id="Picture 30"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image063.png"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:42.55pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>2.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Pilih <b>Edit </b>(Port yang sudah dibuka
# adalah port 22 untuk komunikasi lewat SSH). </span><span lang=EN-US><img
# border=0 width=624 height=25 id="Picture 65"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image064.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:42.55pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Nah
# sekarang kita akan menambahkan port 25200 untuk komunikasi TCP dari Thinger.IO.
# Sekaligus menambahkan port 80 untuk HTTP</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:42.55pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Pilih
# <b>Add Rule</b></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:60.55pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>-<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Pada <b>Type </b>tambahkan HTTP </span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:60.55pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>-<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Pada <b>Type </b>tambahkan juga <b>Custom
# TCP Rule </b>dan <b>Port Range </b></span><b><span lang=EN-US style='font-size:
# 12.0pt;line-height:150%;font-family:Wingdings'>à</span></b><b><span lang=EN-US
# style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>
# 25200</span></b></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:60.55pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>-<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Kemudian <b>Save</b></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:42.55pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=540 height=213 id="Picture 84"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image065.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:42.55pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>&nbsp;</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:21.3pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><b><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>6.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span></b><b><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>MENGGUNAKAN THINGER.IO DENGAN UBUNTU
# SERVER KITA SENDIRI</span></b></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:21.3pt;margin-bottom:.0001pt;text-indent:1.0cm;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Kita akan melakukan percobaan pada
# pertemuan hari Jum’at kemarin menggunakan Thinger.io tetapi menggunakan Ubuntu
# Server kita.</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>1.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Buka web browser pada Ubuntu Server anda,
# ketikkan url pada Ubuntu Instance pada <b>alamat IPv4 Public IP</b> (dapat
# dilihat di Ubuntu Instance)</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=342 height=89 id="Picture 11"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image066.png"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Maka
# akan tertampil tampilan halaman web login dari Thinger.IO</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=576 height=283 id="Picture 15"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image067.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>2.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Karena kita menggunakan Thinger.IO server
# lewat Ubuntu, maka kita harus membuat akun baru dengan menggunakan alamat email
# yang kemarin. Pilih saja <b>Create an account. </b>Isikan data yang diperlukan
# kemudian Sign Up, maka anda akan langsung masuk ke halaman Console Thinger
# tanpa harus verifikasi email terlebih dahulu.</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Tampilan
# console Thinger.IO : </span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:35.45pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=565 height=261 id="Picture 156"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image068.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:42.55pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Di
# situ kita tidak dibatasi dalam penggunaan device karena memang kita menggunakan
# server ubuntu sesuai hasil develop kita sendiri. Jadi ya sesuka kita </span><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:Wingdings'>J</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:42.55pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>3.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Membuat device baru pada menu <b>Device.</b></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:42.55pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Pilih
# Add Device untuk menambahkan device baru</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:42.55pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=136 height=126 id="Picture 70"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image069.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:42.55pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>4.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Isikan Device ID dan description sesuai
# Anda. </span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:42.55pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Untuk
# device credentials , pilih saja Generate Random  Credential</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:42.55pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=499 height=403 id="Picture 82"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image070.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:42.55pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>5.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Jika sudah terisi jangan lupa Add Device,
# maka akan tertampil pesan berikut ini</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:42.55pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=555 height=47 id="Picture 72"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image071.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:42.55pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>6.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Buka Arduino IDE Anda, pada source code
# ThingerIO yang kemarin untuk menyalakan 2 buah LED.</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:42.55pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Karena
# kita menggunakan server Ubuntu sendiri, tambahkan pada code kemarin dengan
# fungsi #define berikut :</span></p>
#
# <div style='border:solid windowtext 1.0pt;padding:1.0pt 4.0pt 1.0pt 4.0pt;
# margin-left:72.0pt;margin-right:0cm'>
#
# <p class=MsoListParagraphCxSpMiddle style='margin:0cm;margin-bottom:.0001pt;
# line-height:normal;border:none;padding:0cm'><span lang=EN-US style='font-family:
# "Times New Roman",serif'>#define _DEBUG_</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin:0cm;margin-bottom:.0001pt;
# line-height:normal;border:none;padding:0cm'><span lang=EN-US style='font-family:
# "Times New Roman",serif'>#define _DISABLE_TLS_</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin:0cm;margin-bottom:.0001pt;
# line-height:normal;border:none;padding:0cm'><span lang=EN-US style='font-family:
# "Times New Roman",serif'>#define THINGER_SERVER &quot;<b>ALAMAT IPv4 PUBLIC IP</b>&quot;</span></p>
#
# </div>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:42.55pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Jangan
# lupa ubah atau sesuaikan dengan kode ini</span></p>
#
# <div style='border:solid windowtext 1.0pt;padding:1.0pt 4.0pt 1.0pt 4.0pt;
# margin-left:72.0pt;margin-right:0cm'>
#
# <p class=MsoListParagraphCxSpMiddle style='margin:0cm;margin-bottom:.0001pt;
# line-height:normal;border:none;padding:0cm'><span lang=EN-US style='font-size:
# 12.0pt;font-family:"Times New Roman",serif'>#define USERNAME &quot;username
# thinger.io&quot;</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin:0cm;margin-bottom:.0001pt;
# line-height:normal;border:none;padding:0cm'><span lang=EN-US style='font-size:
# 12.0pt;font-family:"Times New Roman",serif'>#define DEVICE_ID &quot;id device&quot;</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin:0cm;margin-bottom:.0001pt;
# line-height:normal;border:none;padding:0cm'><span lang=EN-US style='font-size:
# 12.0pt;font-family:"Times New Roman",serif'>#define DEVICE_CREDENTIAL
# &quot;device credential&quot;</span></p>
#
# </div>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:42.55pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>7.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Simpan dan Upload program pada board Node
# MCU. </span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:42.55pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>&nbsp;</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:42.55pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>8.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>(Untuk rangkaian sama seperti yg kemarin)</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:42.55pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>9.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Cek pada menu <b>Device, </b>lihat apakah
# Device sudah terkoneksi atau belum</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:42.55pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=555 height=215 id="Picture 1"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image072.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:42.55pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif'>Pada
# serial port.</span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:42.55pt;margin-bottom:.0001pt;line-height:150%'><span
# lang=EN-US><img border=0 width=534 height=284 id="Picture 2"
# src="https://raw.githubusercontent.com/alldino/DTS-IoT/master/image/img/image073.jpg"></span></p>
#
# <p class=MsoListParagraphCxSpMiddle style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:42.55pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>10.<span style='font:7.0pt "Times New Roman"'>&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Pada Thinger.IO, buka menu dashboard dan <b>Add
# new Dashboard </b>(Buat dashboard yg sama seperti yang kemarin dan tambahkan
# widget,<b> read : 2 buah on/state button</b>)</span></p>
#
# <p class=MsoListParagraphCxSpLast style='margin-top:0cm;margin-right:0cm;
# margin-bottom:0cm;margin-left:42.55pt;margin-bottom:.0001pt;text-indent:-18.0pt;
# line-height:150%'><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>11.<span style='font:7.0pt "Times New Roman"'>&nbsp;
# </span></span><span lang=EN-US style='font-size:12.0pt;line-height:150%;
# font-family:"Times New Roman",serif'>Jika sudah, Turn ON/OFF 2 buah LED
# menggunakan widget yang tadi dibuat. Jika berhasil maka lanjut saja ke
# percobaan publish Sonar dan subscribe Servo.</span></p>
#
# <p class=MsoNormal><span lang=EN-US>&nbsp;</span></p>
#
# </div>
#
# </body>
#
# </html>
